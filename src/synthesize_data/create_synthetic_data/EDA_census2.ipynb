# %%
import pandas as pd
import numpy as np
import ucimlrepo
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
census_income_kdd = fetch_ucirepo(id=117) 
  
# data (as pandas dataframes) 
X = census_income_kdd.data.features 
y = census_income_kdd.data.targets 
  
# metadata 
print(census_income_kdd.metadata) 
  
# variable information 
print(census_income_kdd.variables)
# Out:
# {'uci_id': 117, 'name': 'Census-Income (KDD)', 'repository_url': 'https://archive.ics.uci.edu/dataset/117/census+income+kdd', 'data_url': 'https://archive.ics.uci.edu/static/public/117/data.csv', 'abstract': 'This data set contains weighted census data extracted from the 1994 and 1995 current population surveys conducted by the U.S. Census Bureau.', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 299285, 'num_features': 41, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Occupation', 'Education Level', 'Marital Status', 'Race', 'Sex', 'Other', 'Nationality', 'Income'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2000, 'last_updated': 'Fri Mar 08 2024', 'dataset_doi': '10.24432/C5N30T', 'creators': [], 'intro_paper': None, 'additional_info': {'summary': "This data set contains weighted census data extracted from th
# ...

# %%
X
# Out:
#         AAGE                          ACLSWKR  ADTINK  ADTOCC  \
# 0         73                  Not in universe       0       0
# 1         58   Self-employed-not incorporated       4      34
# 2         18                  Not in universe       0       0
# 3          9                  Not in universe       0       0
# 4         10                  Not in universe       0       0
# ...      ...                              ...     ...     ...
# 199518    87                  Not in universe       0       0
# 199519    65       Self-employed-incorporated      37       2
# 199520    47                  Not in universe       0       0
# 199521    16                  Not in universe       0       0
# 199522    32                          Private      42      30
#
#                                AHGA            AHSCOL  \
# 0              High school graduate   Not in universe
# 1        Some college but no degree   Not in universe
# 2                        10th grade       High school
# ...

# %%
# reading from zip file is the same as uciml api
# df_trash = pd.read_csv("D:\SummerResearch\data\census2\census-income.data")
# df_trash

# %%
X.isnull().sum()
# Out:
# AAGE             0
# ACLSWKR          0
# ADTINK           0
# ADTOCC           0
# AHGA             0
# AHSCOL           0
# AMARITL          0
# AMJIND           0
# AMJOCC           0
# ARACE            0
# AREORGN          0
# ASEX             0
# AUNMEM           0
# AUNTYPE          0
# AWKSTAT          0
# CAPGAIN          0
# GAPLOSS          0
# DIVVAL           0
# FILESTAT         0
# GRINREG          0
# GRINST         708
# HHDFMX           0
# HHDREL           0
# MARSUPWRT        0
# MIGMTR1      99696
# MIGMTR3      99696
# MIGMTR4      99696
# MIGSAME          0
# MIGSUN       99696
# NOEMP            0
# PARENT           0
# PEFNTVTY      6713
# PEMNTVTY      6119
# PENATVTY      3393
# PRCITSHP         0
# SEOTR            0
# VETQVA           0
# VETYN            0
# WKSWORK          0
# AHRSPAY          0
# year             0
# dtype: int64

# %%
X.drop(columns=['MIGMTR1', 'MIGMTR3', 'MIGMTR4', 'MIGSUN'], inplace=True)
X.dropna(inplace=True)
X
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18204\2184146956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop(columns=['MIGMTR1', 'MIGMTR3', 'MIGMTR4', 'MIGSUN'], inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_18204\2184146956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.dropna(inplace=True)
#         AAGE                          ACLSWKR  ADTINK  ADTOCC  \
# 0         73                  Not in universe       0       0
# 1         58   Self-employed-not incorporated       4      34
# 2         18                  Not in universe       0       0
# ...
